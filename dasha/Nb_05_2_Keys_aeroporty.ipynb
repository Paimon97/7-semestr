# %% [markdown]
# ### Подключаем пакет

# %%
import numpy as np
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## Аэропорты
# ### Загрузка данных

# %%
airports = pd.read_csv('~/Dropbox/ My cource/2019-20 Data Analisis/datasets/airports.csv')
airports.head()
# Out:
#    1                               Goroka Airport        Goroka  \
# 0  2                               Madang Airport        Madang
# 1  3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 2  4                               Nadzab Airport        Nadzab
# 3  5  Port Moresby Jacksons International Airport  Port Moresby
# 4  6                  Wewak International Airport         Wewak
#
#    Papua New Guinea  GKA  AYGA  -6.081689834590001  145.391998291  5282  10  \
# 0  Papua New Guinea  MAG  AYMD           -5.207080     145.789001    20  10
# 1  Papua New Guinea  HGU  AYMH           -5.826790     144.296005  5388  10
# 2  Papua New Guinea  LAE  AYNZ           -6.569803     146.725977   239  10
# 3  Papua New Guinea  POM  AYPY           -9.443380     147.220001   146  10
# 4  Papua New Guinea  WWK  AYWK           -3.583830     143.669006    19  10
#
#    U  Pacific/Port_Moresby  airport  OurAirports
# 0  U  Pacific/Port_Moresby  airport  OurAirports
# ...

# %%
columns = ['Airport ID', 'Name', 'City', 'Country', 'IATA', 
           'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 
           'DST', 'Tz database', 'Type', 'Source']
airports = pd.read_csv('~/Dropbox/ My cource/2019-20 Data Analisis/datasets/airports.csv', 
                       names = columns)
airports.head()
# Out:
#    Airport ID                                         Name          City  \
# 0           1                               Goroka Airport        Goroka
# 1           2                               Madang Airport        Madang
# 2           3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3           4                               Nadzab Airport        Nadzab
# 4           5  Port Moresby Jacksons International Airport  Port Moresby
#
#             Country IATA  ICAO  Latitude   Longitude  Altitude Timezone DST  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282       10   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20       10   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388       10   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239       10   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146       10   U
#
#             Tz database     Type       Source
# ...

# %%
airports.count()
# Out:
# Airport ID     7184
# Name           7184
# City           7140
# Country        7184
# IATA           7182
# ICAO           7184
# Latitude       7184
# Longitude      7184
# Altitude       7184
# Timezone       7184
# DST            7184
# Tz database    7184
# Type           7184
# Source         7184
# dtype: int64

# %%
airports.City.unique()
# Out:
# array(['Goroka', 'Madang', 'Mount Hagen', ..., 'Wuhu', 'Shanshan',
#        'Yingkou'], dtype=object)

# %%
airports[airports.IATA.str.len()<3]
# Out:
#       Airport ID                          Name             City      Country  \
# 56            57           Forestville Airport      Forestville       Canada
# 103          104          Pitt Meadows Airport     Pitt Meadows       Canada
# 205          207                 Blida Airport            Blida      Algeria
# 206          208             Bou Saada Airport        Bou Saada      Algeria
# 211          213               Reggane Airport           Reggan      Algeria
# 213          215           Ain Oussera Airport      Ain Oussera      Algeria
# 216          218              Mecheria Airport         Mecheria      Algeria
# 217          219              Relizane Airport         Relizane      Algeria
# 223          226              Bou Sfer Airport         Bou Sfer      Algeria
# 229          232        Sidi Bel Abbes Airport   Sidi Bel Abbes      Algeria
# 247          250                    Wa Airport               Wa        Ghana
# ...

# %%
airports[airports.IATA.str.len()<3]["IATA"].unique()
# Out:
# array(['\\N'], dtype=object)

# %%
airports=airports.replace("\\N",np.nan)
airports['Tz database'].unique()
# Out:
# array(['Pacific/Port_Moresby', 'America/Godthab', 'America/Thule',
#        'Atlantic/Reykjavik', 'America/Toronto', 'America/Winnipeg',
#        'America/Halifax', 'America/St_Johns', 'America/Vancouver',
#        'America/Edmonton', 'America/Coral_Harbour',
#        'America/Dawson_Creek', 'America/Regina', 'Africa/Algiers',
#        'Africa/Porto-Novo', 'Africa/Ouagadougou', 'Africa/Accra',
#        'Africa/Abidjan', 'Africa/Lagos', 'Africa/Niamey', 'Africa/Tunis',
#        'Africa/Lome', 'Europe/Brussels', 'Europe/Berlin',
#        'Europe/Tallinn', 'Europe/Helsinki', 'Europe/Mariehamn',
#        'Europe/London', 'Europe/Guernsey', 'Europe/Jersey',
#        'Europe/Isle_of_Man', 'Atlantic/Stanley', 'Europe/Amsterdam',
#        'Europe/Dublin', 'Europe/Copenhagen', 'Atlantic/Faeroe',
#        'Europe/Luxembourg', 'Europe/Oslo', 'Arctic/Longyearbyen',
#        'Europe/Warsaw', 'Europe/Stockholm', 'Africa/Johannesburg',
# ...

# %%
# отберем аэропорты Европы
euro_air = airports[airports['Tz database'].str.contains('Europe', na=False)]
euro_air
# Out:
#       Airport ID                                    Name               City  \
# 296          299  Antwerp International Airport (Deurne)            Antwerp
# 297          300                    Beauvechain Air Base        Beauvechain
# 298          301                  Kleine Brogel Air Base      Kleine Brogel
# 299          302                        Brussels Airport           Brussels
# 300          303                     Jehonville Air Base            Bertrix
# 301          304        Brussels South Charleroi Airport          Charleroi
# 302          305                       Chièvres Air Base           Chievres
# 303          306                       Koksijde Air Base           Koksijde
# 304          307                      Florennes Air Base          Florennes
# 305          308                        Wevelgem Airport  Kortrijk-vevelgem
# 306          309                           Liège Airport              Liege
# ...

# %%
euro_air['Country'].unique()
# Out:
# array(['Belgium', 'Germany', 'Estonia', 'Finland', 'United Kingdom',
#        'Guernsey', 'Jersey', 'Isle of Man', 'Netherlands', 'Ireland',
#        'Denmark', 'Luxembourg', 'Norway', 'Poland', 'Sweden', 'Spain',
#        'Albania', 'Bulgaria', 'Cyprus', 'Croatia', 'France', 'Greece',
#        'Hungary', 'Italy', 'Slovenia', 'Czech Republic', 'Malta',
#        'Austria', 'Portugal', 'Bosnia and Herzegovina', 'Romania',
#        'Switzerland', 'Turkey', 'Moldova', 'Macedonia', 'Gibraltar',
#        'Serbia', 'Montenegro', 'Slovakia', 'Ukraine', 'Russia', 'Belarus',
#        'Latvia', 'Lithuania', 'United States'], dtype=object)

# %%
euro_air[euro_air['Country'] == 'United States']
# Out:
#       Airport ID             Name      City        Country IATA  ICAO  \
# 6489        9403  Taszár Air Base  Columbus  United States  TZR  LHTA
#
#        Latitude  Longitude  Altitude Timezone DST      Tz database     Type  \
# 6489  46.393101    17.9175       531        1   A  Europe/Budapest  airport
#
#            Source
# 6489  OurAirports

# %%
airports[airports['IATA'] == 'TZR']
# Out:
#       Airport ID             Name      City        Country IATA  ICAO  \
# 6489        9403  Taszár Air Base  Columbus  United States  TZR  LHTA
#
#        Latitude  Longitude  Altitude Timezone DST      Tz database     Type  \
# 6489  46.393101    17.9175       531        1   A  Europe/Budapest  airport
#
#            Source
# 6489  OurAirports

# %%
airports[airports['City'] == 'Columbus']
# Out:
#       Airport ID                                 Name      City  \
# 3459        3674   Rickenbacker International Airport  Columbus
# 3541        3759  Port Columbus International Airport  Columbus
# 3984        4255        Columbus Metropolitan Airport  Columbus
# 5591        7511        Ohio State University Airport  Columbus
# 6489        9403                      Taszár Air Base  Columbus
# 6946       11816           Columbus Municipal Airport  Columbus
# 6977       11847           Columbus Municipal Airport  Columbus
#
#             Country IATA  ICAO   Latitude  Longitude  Altitude Timezone  DST  \
# 3459  United States  LCK  KLCK  39.813801 -82.927803       744       -5    A
# 3541  United States  CMH  KCMH  39.998001 -82.891899       815       -5    A
# 3984  United States  CSG  KCSG  32.516300 -84.938904       397       -5    A
# 5591  United States  OSU  KOSU  40.079800 -83.072998       905       -5    U
# ...

# %%
euro_air[euro_air['Altitude']>5000]
# Out:
#       Airport ID                           Name        City      Country IATA  \
# 1635        1680                Samedan Airport     Samedan  Switzerland  SMV
# 1649        1694     Sivas Nuri Demirağ Airport       Sivas       Turkey  VAS
# 1673        1724  Erzurum International Airport     Erzurum       Turkey  ERZ
# 1675        1728        Van Ferit Melen Airport         Van       Turkey  VAN
# 4459        5796                   Kars Airport        Kars       Turkey  KSY
# 4462        5799                   Ağrı Airport        Agri       Turkey  AJI
# 5049        6479             Courchevel Airport  Courcheval       France  CVF
# 5875        8080               Méribel Altiport     Ajaccio       France  MFX
#
#       ICAO   Latitude  Longitude  Altitude Timezone DST      Tz database  \
# 1635  LSZS  46.534100   9.884110      5600        1   E    Europe/Zurich
# 1649  LTAR  39.813801  36.903500      5239        3   E  Europe/Istanbul
# ...

# %%
euro_air[euro_air['Altitude']==euro_air['Altitude'].max()]
# Out:
#       Airport ID                Name        City Country IATA  ICAO  \
# 5049        6479  Courchevel Airport  Courcheval  France  CVF  LFLJ
#
#        Latitude  Longitude  Altitude Timezone DST   Tz database     Type  \
# 5049  45.396702    6.63472      6588        1   E  Europe/Paris  airport
#
#            Source
# 5049  OurAirports

# %%
airports[airports['City']=='Moscow']
# Out:
#       Airport ID                                Name    City Country IATA  \
# 2825        2985  Sheremetyevo International Airport  Moscow  Russia  SVO
# 2828        2988       Vnukovo International Airport  Moscow  Russia  VKO
# 3794        4029    Domodedovo International Airport  Moscow  Russia  DME
# 4065        4360                      Bykovo Airport  Moscow  Russia  BKA
# 6197        8661     Ostafyevo International Airport  Moscow  Russia  NaN
# 7115       11986                   Myachkovo Airport  Moscow  Russia  NaN
#
#       ICAO   Latitude  Longitude  Altitude Timezone  DST    Tz database  \
# 2825  UUEE  55.972599  37.414600       622        3    N  Europe/Moscow
# 2828  UUWW  55.591499  37.261501       685        3    N  Europe/Moscow
# 3794  UUDD  55.408798  37.906300       588        3    N  Europe/Moscow
# 4065  UUBB  55.617199  38.060001       427        3    N  Europe/Moscow
# 6197  UUMO  55.511700  37.507198       568        3    N  Europe/Moscow
# ...

# %%
moskow= airports[(airports['City'] == 'Moscow') & ~(airports['IATA'].isna()) ]

# %%
list_msk = ['SVO','VKO','DME','BKA']
airports[airports['IATA'].isin(list_msk)]
# Out:
#       Airport ID                                Name    City Country IATA  \
# 2825        2985  Sheremetyevo International Airport  Moscow  Russia  SVO
# 2828        2988       Vnukovo International Airport  Moscow  Russia  VKO
# 3794        4029    Domodedovo International Airport  Moscow  Russia  DME
# 4065        4360                      Bykovo Airport  Moscow  Russia  BKA
#
#       ICAO   Latitude  Longitude  Altitude Timezone DST    Tz database  \
# 2825  UUEE  55.972599  37.414600       622        3   N  Europe/Moscow
# 2828  UUWW  55.591499  37.261501       685        3   N  Europe/Moscow
# 3794  UUDD  55.408798  37.906300       588        3   N  Europe/Moscow
# 4065  UUBB  55.617199  38.060001       427        3   N  Europe/Moscow
#
#          Type       Source
# 2825  airport  OurAirports
# 2828  airport  OurAirports
# 3794  airport  OurAirports
# 4065  airport  OurAirports

# %%
columns = ['Airline','Airline ID','Source airport','Source airport ID','Destination airport',
            'Destination airport ID','Codeshare','Stops','Equipment']
routes = pd.read_csv('~/Dropbox/ My cource/2019-20 Data Analisis/datasets/routes.csv', names = columns)
routes.head()
# Out:
#   Airline Airline ID Source airport Source airport ID Destination airport  \
# 0      2B        410            AER              2965                 KZN
# 1      2B        410            ASF              2966                 KZN
# 2      2B        410            ASF              2966                 MRV
# 3      2B        410            CEK              2968                 KZN
# 4      2B        410            CEK              2968                 OVB
#
#   Destination airport ID Codeshare  Stops Equipment
# 0                   2990       NaN      0       CR2
# 1                   2990       NaN      0       CR2
# 2                   2962       NaN      0       CR2
# 3                   2990       NaN      0       CR2
# 4                   4078       NaN      0       CR2

# %%
routes[routes['Source airport'].isin(moskow.IATA)]['Source airport'].value_counts()
# Out:
# DME    324
# SVO    199
# VKO     86
# Name: Source airport, dtype: int64
